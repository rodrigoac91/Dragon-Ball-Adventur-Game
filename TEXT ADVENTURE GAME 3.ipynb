# %%
"""""
Created on Fri Oct 22  18:50 2021

@author: Francisco Rodrigo Alonso Castellanos

"""

"""
DocString: 

Introduction:
    This game is based on the cartoon Dragon Ball Z (1989). 
    It consists of 4 stages, you can find functions in
    the game to go to the next level, you can try again, or you can
    lose. You must know basic mathematic and luck with your elections.
    
    Round 1) Select a player.
    Round 2) Attack the enemy with a power.
    Round 3) You have to sum the numbers that are in the instructions.
    Round 4) You have to choose a number from those shown in the instructions.
    Round 5) Randon Game. Good Luck. 
    Enjoy the game.
"""
#import package random as rd
import random as rd 

#defining the first room
def room_1():
    #defining the variables pas and name
    pas = ""
    name = input (prompt="""What is your name?\n
""")
    #using a loop function to assure that the user use a correct possible answer
    while True:
        print(f"""
{'-' * 40}\n""")
        #declaring a variable that stores the introduction text
        player_user = input( prompt = f"""
Hi {name.capitalize().strip()}! Welcome to Dragon Ball Z! You must help Kakaroto
and friends to save the galaxy. The powers of Kakaroto, friends and yours will
save the world,fight versus villains, they want to kill them and government the 
Galaxy, you don´t leave they do it!! You must be ready and control your ki. 
Remember read the instructions and always think positively.

You have the power now!! 
{'-' * 100}\n
Select a fighter for your first fight:
    A) Kakaroto
    B) Vegeta
    C) Gohan\n
""")
        #Declaring the variables that are rejected
        for strangechar in ")(./-!?":
            player_user = player_user.replace(strangechar, '')

            player_user = player_user.casefold().strip()
#The firts conditional to evaluate the possible answer of the player with implementation of case-insensitive string matching 
        if player_user.casefold().strip() in ('a','b','c'):
            pas = "correct"
#The second conditional to evaluate the possible answer with a minimun of three letters
        if len(player_user) < 3 and pas != "correct":
                print("You must type at least three letters or write A, B or C.")
                input(prompt="Press ENTER to continue\n")        
#Adding possible conditions of the player's answers with implementation of case-insensitive string match     
        elif "kakaroto" in player_user.casefold() or player_user.casefold() in "kakaroto":
                print("You are Kakaroto!! The most powerful warrior on the entire planet Earth.\n")
                room_2() #this move the player to the second room
                break
#Adding possible conditions of the player's answers with implementation of case-insensitive string match
        elif "vegeta" in player_user.casefold() or player_user.casefold() in "vegeta":
                print("You are Vegeta!! Prince of the warrior race.\n") 
                room_2() #this move the player to the second room
                break
#Adding possible conditions of the player's answers with implementation of case-insensitive string match
        elif "gohan" in player_user.casefold() or player_user.casefold() in "gohan":
                print("You are Gohan!! A warrior with hidden power.\n")
                room_2() #this move the player to the second room
                break
#Adding possible conditions of the player's answers with implementation of case-insensitive string match
        elif player_user.casefold()== 'a':
                print("You are Kakaroto!! The most powerful warrior on the entire planet Earth.\n")
                room_2() #this move the player to the second room
                break
#Adding possible conditions of the player's answers with implementation of case-insensitive string match
        elif player_user.casefold()=='b':
                print("You are Vegeta!! Prince of the warrior race.\n")
                room_2() #this move the player to the second room
                break
#Adding possible conditions of the player's answers with implementation of case-insensitive string match 
        elif player_user.casefold()=='c':
                print("You are Gohan!! A warrior with hidden power.\n")
                room_2() #this move the player to the second room
                break
        #addin an else clause with instruction
        else:
                print("You have to SELECT A, B or C, please!")
                input(prompt="Press ENTER to continue\n")

#defining the second room 

def room_2():
    #defining the variable pas1
    pas1=""
    print(f"""
{'-' * 100}\n""")
    #using a loop function to assure that the user use a correct possible answer
    while True: 
        print(
"You are in Nameku, you have to fight versus Freezer and save your friends.")
        power_attack = input(prompt="""
You have to choose a power to attack Freezer
A) Star Light
B) Kame Hame Ha
C) Genkidama\n
""") 
        #Declaring the variables that are rejected
        for strangechar in ")(./-!?":
            power_attack = power_attack.replace(strangechar, '')
#The firts conditional to evaluate the possible answer of the player with implementation of case-insensitive string matching
        if power_attack.casefold().strip() in ('a','b','c'):
            pas1 = "correct"
            
#The second conditional to evaluate the possible answer with a minimun of three letters
        if len(power_attack) < 3 and pas1 != "correct":
            print("You must type at least three letters or write A, B or C.")
            input(prompt="Press ENTER to continue\n") #The player has to write the correct answer
            
#Adding possible conditions of the player's answers with implementation of case-insensitive string matching
        elif "star light" in power_attack.casefold() or power_attack.casefold() in "star light":
            print("Your attack power is low. You're Dead! Try again!\n")
            input(prompt="Press ENTER to continue\n") #The player can try again 
#Adding possible conditions of the player's answers with implementation of case-insensitive string matching            
        elif "kame hame ha" in power_attack.casefold() or power_attack.casefold() in "kame hame ha":
            print("Your attack power is low, You're Dead! Try again!\n") 
            input(prompt="Press ENTER to continue\n") #The player can try again 
#Adding possible conditions of the player's answers with implementation of case-insensitive string matching            
        elif "genkidama" in power_attack.casefold() or power_attack.casefold() in "genkidama":
            print("Freezer is Dead!! You saved Nameku!\n")  
            room_3() #this move the player to the third room
            break
#Adding possible conditions of the player's answers with implementation of case-insensitive string matching
        elif power_attack.casefold()=='a':
            print("Your attack power is low, You're Dead! Try again!\n")
            input(prompt="Press ENTER to continue\n") #The player can try again
#Adding possible conditions of the player's answers with implementation of case-insensitive string matching                     
        elif power_attack.casefold()=='b':
            print("Your attack power is low, You're Dead! Try again!\n")
            input(prompt="Press ENTER to continue\n") #The player can try again
#Adding possible conditions of the player's answers with implementation of case-insensitive string matching            
        elif power_attack.casefold()=='c':
            print("Freezer is Dead!! You saved Nameku!\n")
            room_3() #this move the player to the third room
            break
        #addin an else clause with instruction
        else:
            print("You have to SELECT A, B or C, please! Try again.\n")
            input(prompt="Press ENTER to continue\n") #The player has to write the correct answer


#defining the third room
def room_3():
    print(f"""
{'-' * 40}\n""")
    #defining the variable errormsg
    errormsg = "Variable not valid."
    #using a loop function to assure that the user use a correct possible answer
    while True:
        plus_one=input(prompt = f"""
Something is happening on Earth, you have to go quickly.\n
You have to save Earth and you will fight versus Cell,
he is weak and you have the option to win the battle.\n
You have to sum 2 and 2 and write the correct number (No text).\n
""")
    #Defining the possible response exception
        try:
            plus_one = int(plus_one)
            
        except: 
            print(f"""{errormsg}""")
#The conditional to evaluate the answer of the player in case that is correct
        if plus_one == 4:
            print("You are allow to go to room 4")
            room_4() #this move the player to the fourth room
            break
#Adding else when the answer is incorrect
        else:
            print(f"""Try again""")
            #room_3()
            continue
               
                
 #defining the fourth room                  
def room_4():
    print(f"""
{'-' * 40}\n""")    
    print("You got the next level. Let's fight!!\n")
    #defining the variable errormsg and bonus_game
    bonus_game =""
    errormsg = ""
    print(f"""
{'-' * 40}\n""")
    print(f"""
Boo is a powerful fighter, you must save the world, 
now he wants to play with your mind. Come on guess the question.""")      
   
    #using a loop function to assure that the user use a correct possible answer
    while True:
        #Declaring the variables that are rejected
        for strangechar in ")(./-!?":
            bonus_game = bonus_game.replace(strangechar, '')
            

        bonus_game=input(prompt=f"""
Boo is a powerful fighter, you must guess his power only from the following four options: 
\nA)50
B)75
C)100
D)125\n
You can and get the random game.
You have to write the number ex.50, 75, 100 or 125. If you write letter it is no valid.
You only have one chance.\n
""")
        
#The conditional to evaluate the answer of the player            
        if  errormsg == "error":
            print("Try again")
            room_4() #this move the player to the fourth room
            break
    #The conditional to evaluate the answer of the player   
        elif  int(bonus_game)== 50:
            fail() #this move the player to the the end game
            break
    #The conditional to evaluate the answer of the player 
        elif int(bonus_game)== 75:
            fail() #this move the player to the the end game
            break
    #The conditional to evaluate the answer of the player 
        elif int(bonus_game)== 125:
            fail() #this move the player to the the end game
            break
    #The conditional to evaluate the answer of the player 
        elif int(bonus_game)== 100:
            print("")
            random_ev() #this move the player to the "random" room
            break
  #Adding else when the answer is incorrect  
        else:
            print("You have to write 50, 75, 100 or 125, please! Try again.\n")
            room_4() #this move the player to the fourth room
            break

#defining the "random" room           
def random_ev():
    print(f"""
{'-' * 40}\n""")
    print("Random Game, Good Luck!")
    input(prompt="Press ENTER to continue\n")
#defining the variable random_event with the possible answers     
    random_event = ['rd_1', 'rd_2', 'rd_3']
#defining the variable random_choice
    random_choice = rd.choice(random_event)
    #The conditional to evaluate the random choice
    if random_choice == 'rd_1':
        print("Vegeta is coming but he is weak, You Lost!!")
        fail()
    #The conditional to evaluate the random choice    
    elif random_choice == 'rd_2':
        print("Gohan arrived and he helped you. You Win!!")
        input(prompt='<Press enter to exit>\n')
     #The conditional to evaluate the random choice   
    elif random_choice == 'rd_3':
        print("Gotenks arrived but he is weak, You Lost!!")
        fail()
        
    else:
        print("something wrong happened")
        
#defining the fail room                
def fail():
    print(f"""
{'-' * 40}\n""")
    print("You failed, sorry!")
    print("GAME OVER!!!")
    input(prompt='<Press enter to exit>\n')
    
#Calling the start game
room_1()
# Out:
# What is your name?
#
# mariana
#
# ----------------------------------------
#
#
# Hi Mariana! Welcome to Dragon Ball Z! You must help Kakaroto
# and friends to save the galaxy. The powers of Kakaroto, friends and yours will
# save the world,fight versus villains, they want to kill them and government the
# Galaxy, you don´t leave they do it!! You must be ready and control your ki.
# Remember read the instructions and always think positively.
#
# You have the power now!!
# ----------------------------------------------------------------------------------------------------
#
# Select a fighter for your first fight:
#     A) Kakaroto
#     B) Vegeta
#     C) Gohan
#
# k
# You must type at least three letters or write A, B or C.
# Press ENTER to continue
#
#
# ----------------------------------------
#
#
# Hi Mariana! Welcome to Dragon Ball Z! You must help Kakaroto
# and friends to save the galaxy. The powers of Kakaroto, friends and yours will
# ...
